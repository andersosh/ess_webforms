# %%
import pandas as pd
import csv
import openpyxl
import datetime
from datetime import datetime
from openpyxl import Workbook, load_workbook
from openpyxl.utils import get_column_letter
from pdfrw import PdfWriter


# save data csv file as xlsx in order to manipulate it
wb = openpyxl.Workbook()
ws = wb.active
with open("Purchase Request.csv") as f:
    reader = csv.reader(f, delimiter=",")
    for row in reader:
        ws.append(row)
        
wb.save("Purchase Request.xlsx")

# %%
wb1 = load_workbook("Purchase Request.xlsx")
wb2 = load_workbook("ess_purchase_request.xlsx")
source_sheet = wb1["Sheet"]
ws1 = wb2["Sheet1"]
ws2 = wb2["Sheet2"]
worksheet = wb.active
for row in range (2,source_sheet.max_row+1):
    wbx = str(row) + "-" + source_sheet["B" + str(row)].value + ".xlsx"
    print(wbx)
    for col in range (1, source_sheet.max_column+1):
        #copy from source sheet to worksheet
        ws2.cell(row=2, column=col).value = source_sheet.cell(row=row,column=col).value   
        # map data to proper cell         
        #name
        ws1["B7"].value = ws2["B2"].value
        #phone
        ws1["B8"].value = ws2["C2"].value
        #email
        ws1["B9"].value = ws2["D2"].value
        #date
        ws1["B10"].value = ws2["A2"].value
        #need by
        ws1["B11"].value = ws2["E2"].value
        #Rush?
        ws1["A13"].value = ws2["F2"].value
        #vendor name
        ws1["D7"].value = ws2["G2"].value
        #vendor address
        ws1["D8"].value = ws2["H2"].value
        #vendor contact
        ws1["D9"].value = ws2["I2"].value
        #vendor phone
        ws1["D10"].value = ws2["J2"].value
        #vendor email
        ws1["D11"].value = ws2["K2"].value
        #Vendor url
        ws1["D12"].value = ws2["L2"].value
        #purpose
        ws1["F7"].value = ws2["M2"].value
        #M&E tax exempt
        ws1["D13"].value = ws2["N2"].value
        ws1["D14"].value = ws2["O2"].value
        ws1["D15"].value = ws2["P2"].value
        ws1["C16"].value = ws2["Q2"].value
        #PI Budget Approval
        ws1["I10"].value = ws2["R2"].value
        #budget1
        ws1["I16"].value = ws2["S2"].value
        #budget2
        ws1["I17"].value = ws2["T2"].value
        ws1["J17"].value = ws2["U2"].value
        #budget3
        ws1["I18"].value = ws2["V2"].value
        ws1["J18"].value = ws2["W2"].value
        #budget4
        ws1["I19"].value = ws2["X2"].value
        ws1["J19"].value = ws2["Y2"].value 
                #Item1
        #Part
        ws1["A21"].value = ws2["Z2"].value
        #Desc
        ws1["B21"].value = ws2["AA2"].value
        #quant
        ws1["E21"].value = ws2["AB2"].value
        #unit price
        ws1["F21"].value = ws2["AC2"].value
                #Item2
        #Part
        ws1["A22"].value = ws2["AE2"].value
        #Desc
        ws1["B22"].value = ws2["AF2"].value
        #quant
        ws1["E22"].value = ws2["AG2"].value
        #unit price
        ws1["F22"].value = ws2["AH2"].value
                #Item3
        #Part
        ws1["A23"].value = ws2["AJ2"].value
        #Desc
        ws1["B23"].value = ws2["AK2"].value
        #quant
        ws1["E23"].value = ws2["AL2"].value
        #unit price
        ws1["F23"].value = ws2["AM2"].value
                #Item4
        #Part
        ws1["A24"].value = ws2["AO2"].value
        #Desc
        ws1["B24"].value = ws2["AP2"].value
        #quant
        ws1["E24"].value = ws2["AQ2"].value
        #unit price
        ws1["F24"].value = ws2["AR2"].value
                #Item5
        #Part
        ws1["A25"].value = ws2["AT2"].value
        #Desc
        ws1["B25"].value = ws2["AU2"].value
        #quant
        ws1["E25"].value = ws2["AV2"].value
        #unit price
        ws1["F25"].value = ws2["AW2"].value
                #Item6
        #Part
        ws1["A26"].value = ws2["AY2"].value
        #Desc
        ws1["B26"].value = ws2["AZ2"].value
        #quant
        ws1["E26"].value = ws2["BA2"].value
        #unit price
        ws1["F26"].value = ws2["BB2"].value
                #Item7
        #Part
        ws1["A27"].value = ws2["BD2"].value
        #Desc
        ws1["B27"].value = ws2["BE2"].value
        #quant
        ws1["E27"].value = ws2["BF2"].value
        #unit price
        ws1["F27"].value = ws2["BG2"].value
                #Item8
        #Part
        ws1["A28"].value = ws2["BI2"].value
        #Desc
        ws1["B28"].value = ws2["BJ2"].value
        #quant
        ws1["E28"].value = ws2["BK2"].value
        #unit price
        ws1["F28"].value = ws2["BL2"].value
                #Item9
        #Part
        ws1["A29"].value = ws2["BN2"].value
        #Desc
        ws1["B29"].value = ws2["BO2"].value
        #quant
        ws1["E29"].value = ws2["BP2"].value
        #unit price
        ws1["F29"].value = ws2["BQ2"].value
                #Item10
        #Part
        ws1["A30"].value = ws2["BS2"].value
        #Desc
        ws1["B30"].value = ws2["BT2"].value
        #quant
        ws1["E30"].value = ws2["BU2"].value
        #unit price
        ws1["F30"].value = ws2["BV2"].value
        
        
        #Comments
        ws1["A33"].value = ws2["BW2"].value

        
        wb2.save(filename = wbx)
# Out:
# 2-Simon Hans Edasi.xlsx
# 3-Simon Tenzen.xlsx
